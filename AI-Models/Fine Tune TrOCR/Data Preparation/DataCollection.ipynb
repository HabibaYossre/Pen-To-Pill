# %% [markdown]
# # **Script to collect annotated images**

# %%
from google.colab import drive
drive.mount('/content/drive')
images_folder = "/content/drive/MyDrive"
# Out:
# Mounted at /content/drive

# %%
import os
import shutil
import pandas as pd

def collect_images_from_folders(folder_paths, excel_path, output_folder):
    """
    Copies images from given folders to a new folder based on image names from an Excel sheet.

    :param folder_paths: List of 5 folder paths containing images.
    :param excel_path: Path to the Excel sheet containing 'image_name' column.
    :param output_folder: Path to the output folder where matching images will be copied.
    """
    # Ensure output directory exists
    os.makedirs(output_folder, exist_ok=True)

    # Read the Excel file
    df = pd.read_excel(excel_path)

    # Get list of required image names
    image_names = set(df['image'].astype(str))

    # Track found images
    found_images = set()

    # Search in given folders
    for folder in folder_paths:
        if not os.path.exists(folder):
            print(f"Warning: Folder {folder} does not exist.")
            continue

        for file in os.listdir(folder):
            if file in image_names and file not in found_images:
                src_path = os.path.join(folder, file)
                dest_path = os.path.join(output_folder, file)
                shutil.copy2(src_path, dest_path)  # Copy with metadata
                found_images.add(file)

    print(f"Copied {len(found_images)} images to {output_folder}.")
    return found_images

# %%
# Example usage:
folder_paths = ["/content/drive/MyDrive/STP_Competition/cropped_images_habiba", '/content/drive/MyDrive/STP_Competition/cropped_images_haneen', '/content/drive/MyDrive/STP_Competition/cropped_images_mohammed',
                '/content/drive/MyDrive/STP_Competition/cropped_images_renad', '/content/drive/MyDrive/STP_Competition/cropped_images_shrouk']
excel_path = '/content/drive/MyDrive/STP_Competition/DataPreparation.xlsx'
output_folder = '/content/drive/MyDrive/STP_Competition/PrescriptionImagesData'
collect_images_from_folders(folder_paths, excel_path, output_folder)
# Out:
# Copied 1300 images to /content/drive/MyDrive/STP_Competition/PrescriptionImagesData.
# {'Dental_prescription_544_crop_1.jpg',
#  'Neurology_prescription_56_crop_2.jpg',
#  'prescription_Gyne_134_crop_15.jpg',
#  'Neurology_prescription_58_crop_4.jpg',
#  'Dental_prescription_625_crop_9.jpg',
#  'prescription_Gyne_358_crop_6.jpg',
#  'Dental_prescription_607 (1)_crop_6.jpg',
#  'prescription_Gyne_62_crop_6.jpg',
#  'prescription_Gyne_134_crop_4.jpg',
#  'prescription_Gyne_141_crop_9.jpg',
#  'Dental_prescription_605 (1)_crop_7.jpg',
#  'prescription_Gyne_334_crop_3.jpg',
#  'Neurology_prescription_74_crop_3.jpg',
#  'Dental_prescription_611_crop_12.jpg',
#  'prescription_Gyne_403_crop_11.jpg',
#  'Neurology_prescription_72_crop_5.jpg',
#  'prescription_Gyne_419_crop_12.jpg',
#  'Neurology_prescription_57_crop_7.jpg',
#  'Neurology_prescription_60_crop_2.jpg',
#  'prescription_Gyne_419_crop_14.jpg',
#  'Dental_prescription_544_crop_2.jpg',
#  'prescription_Gyne_141_crop_11.jpg',
#  'prescription_Gyne_141_crop_10.jpg',
#  'Neurology_prescription_64_crop_3.jpg',
#  'Dental_prescription_605 (1)_crop_8.jpg',
#  'prescription_opth_198_crop_20.jpg',
#  'prescription_Gyne_81_crop_11.jpg',
#  'prescription_Gyne_402_crop_7.jpg',
#  'prescription_Gyne_475_crop_4.jpg',
#  'Neurology_prescription_72_crop_3.jpg',
#  'prescription_Gyne_335_crop_1.jpg',
#  'prescription_Gyne_403_crop_8.jpg',
#  'Dental_prescription_539_crop_6.jpg',
#  'prescription_opth_193_crop_11.jpg',
#  'Neurology_prescription_79_crop_1.jpg',
#  'Dental_prescription_615_crop_13.jpg',
#  'prescription_opth_202_crop_0.jpg',
#  'prescription_Gyne_141_crop_7.jpg',
#  'Neurology_prescription_80_crop_1.jpg',
#  'prescription_Gyne_13_crop_0.jpg',
#  'prescription_Gyne_81_crop_8.jpg',
#  'prescription_Gyne_149_crop_5.jpg',
#  'Neurology_prescription_69_crop_0.jpg',
#  'prescription_Gyne_19_crop_0.jpg',
#  'prescription_Gyne_447_crop_7.jpg',
#  'prescription_Gyne_416_crop_7.jpg',
#  'prescription_Gyne_447_crop_5.jpg',
#  'Neurology_prescription_68_crop_3.jpg',
#  'prescription_Gyne_435_crop_1.jpg',
#  'prescription_Gyne_85_crop_1.jpg',
#  'Dental_prescription_611 (1)_crop_7.jpg',
#  'Neurology_prescription_67_crop_0.jpg',
#  'Dental_prescription_615_crop_7.jpg',
#  'Dental_prescription_489_crop_7.jpg',
#  'Dental_prescription_542_crop_16.jpg',
#  'prescription_opth_193_crop_8.jpg',
#  'prescription_Gyne_478_crop_12.jpg',
#  'Dental_prescription_609_crop_12.jpg',
#  'prescription_Gyne_19_crop_10.jpg',
#  'prescription_Gyne_59_crop_10.jpg',
#  'prescription_Gyne_334_crop_1.jpg',
#  'prescription_Gyne_19_crop_6.jpg',
#  'prescription_Gyne_156_crop_4.jpg',
#  'Dental_prescription_562_crop_0.jpg',
#  'Dental_prescription_609_crop_0.jpg',
#  'Dental_prescription_557_crop_0.jpg',
#  'Dental_prescription_568_crop_6.jpg',
#  'prescription_Gyne_2_crop_0.jpg',
#  'prescription_Gyne_462_crop_4.jpg',
#  'Dental_prescription_630 (1)_crop_5.jpg',
#  'Dental_prescription_568_crop_0.jpg',
#  'Neurology_prescription_73_crop_0.jpg',
#  'Dental_prescription_615_crop_5.jpg',
#  'Dental_prescription_557_crop_12.jpg',
#  'Dental_prescription_602 (1)_crop_6.jpg',
#  'Dental_prescription_542_crop_11.jpg',
#  'prescription_Gyne_97_crop_2.jpg',
#  'Dental_prescription_488_crop_2.jpg',
#  'Neurology_prescription_74_crop_1.jpg',
#  'prescription_Gyne_430_crop_9.jpg',
#  'Neurology_prescription_71_crop_2.jpg',
#  'prescription_Gyne_382_crop_2.jpg',
#  'Neurology_prescription_63_crop_2.jpg',
#  'prescription_Gyne_134_crop_1.jpg',
#  'prescription_Gyne_389_crop_0.jpg',
#  'prescription_Gyne_141_crop_6.jpg',
#  'prescription_opth_167_crop_14.jpg',
#  'prescription_opth_230_crop_1.jpg',
#  'prescription_opth_161_crop_15.jpg',
#  'prescription_Gyne_62_crop_10.jpg',
#  'prescription_Gyne_354_crop_4.jpg',
#  'Dental_prescription_619_crop_1.jpg',
#  'prescription_opth_161_crop_13.jpg',
#  'prescription_Gyne_337_crop_3.jpg',
#  'Dental_prescription_611_crop_4.jpg',
#  'Dental_prescription_619_crop_6.jpg',
#  'Neurology_prescription_69_crop_10.jpg',
#  'Neurology_prescription_67_crop_10.jpg',
#  'prescription_opth_202_crop_8.jpg',
#  'prescription_Gyne_322_crop_13.jpg',
#  'prescription_opth_261_crop_4.jpg',
#  'prescription_Gyne_430_crop_16.jpg',
#  'Dental_prescription_619_crop_7.jpg',
#  'prescription_Gyne_85_crop_3.jpg',
#  'prescription_Gyne_9_crop_1.jpg',
#  'Dental_prescription_619 (1)_crop_10.jpg',
#  'prescription_opth_167_crop_16.jpg',
#  'prescription_Gyne_18_crop_17.jpg',
#  'prescription_Gyne_393_crop_7.jpg',
#  'prescription_Gyne_85_crop_15.jpg',
#  'prescription_opth_261_crop_23.jpg',
#  'prescription_Gyne_2_crop_13.jpg',
#  'prescription_Gyne_13_crop_1.jpg',
#  'Dental_prescription_543_crop_3.jpg',
#  'prescription_Gyne_343_crop_7.jpg',
#  'prescription_opth_167_crop_5.jpg',
#  'prescription_Gyne_134_crop_0.jpg',
#  'prescription_Gyne_444_crop_0.jpg',
#  'Neurology_prescription_61_crop_6.jpg',
#  'prescription_Gyne_145_crop_4.jpg',
#  'prescription_Gyne_435_crop_2.jpg',
#  'prescription_Gyne_335_crop_13.jpg',
#  'Neurology_prescription_75_crop_6.jpg',
#  'prescription_Gyne_13_crop_3.jpg',
#  'prescription_Gyne_382_crop_0.jpg',
#  'prescription_Gyne_85_crop_5.jpg',
#  'Dental_prescription_611 (1)_crop_2.jpg',
#  'prescription_Gyne_430_crop_8.jpg',
#  'prescription_Gyne_434_crop_13.jpg',
#  'Dental_prescription_542_crop_9.jpg',
#  'prescription_Gyne_419_crop_15.jpg',
#  'prescription_Gyne_156_crop_5.jpg',
#  'Dental_prescription_562_crop_1.jpg',
#  'prescription_opth_198_crop_14.jpg',
#  'prescription_opth_230_crop_9.jpg',
#  'Neurology_prescription_64_crop_11.jpg',
#  'prescription_Gyne_462_crop_0.jpg',
#  'Neurology_prescription_66_crop_2.jpg',
#  'prescription_Gyne_393_crop_19.jpg',
#  'prescription_Gyne_326_crop_8.jpg',
#  'prescription_Gyne_402_crop_11.jpg',
#  'prescription_Gyne_393_crop_5.jpg',
#  'Dental_prescription_611 (1)_crop_12.jpg',
#  'prescription_Gyne_156_crop_18.jpg',
#  'prescription_Gyne_19_crop_12.jpg',
#  'Dental_prescription_625_crop_7.jpg',
#  'prescription_Gyne_434_crop_1.jpg',
#  'prescription_Gyne_62_crop_4.jpg',
#  'Neurology_prescription_67_crop_4.jpg',
#  'prescription_opth_161_crop_24.jpg',
#  'prescription_opth_198_crop_27.jpg',
#  'Neurology_prescription_78_crop_0.jpg',
#  'prescription_Gyne_419_crop_10.jpg',
#  'prescription_Gyne_334_crop_12.jpg',
#  'prescription_Gyne_59_crop_3.jpg',
#  'prescription_Gyne_402_crop_10.jpg',
#  'prescription_Gyne_424_crop_7.jpg',
#  'prescription_Gyne_326_crop_6.jpg',
#  'prescription_Gyne_358_crop_10.jpg',
#  'prescription_Gyne_403_crop_7.jpg',
#  'prescription_Gyne_9_crop_4.jpg',
#  'Neurology_prescription_57_crop_4.jpg',
#  'prescription_Gyne_393_crop_12.jpg',
#  'prescription_Gyne_98_crop_4.jpg',
#  'Dental_prescription_605 (1)_crop_1.jpg',
#  'prescription_Gyne_141_crop_14.jpg',
#  'Neurology_prescription_62_crop_12.jpg',
#  'prescription_Gyne_470_crop_2.jpg',
#  'prescription_Gyne_19_crop_15.jpg',
#  'Neurology_prescription_57_crop_8.jpg',
#  'prescription_opth_230_crop_11.jpg',
#  'Dental_prescription_609_crop_6.jpg',
#  'prescription_opth_197_crop_2.jpg',
#  'prescription_Gyne_435_crop_8.jpg',
#  'Dental_prescription_625_crop_10.jpg',
#  'Dental_prescription_602 (1)_crop_3.jpg',
#  'Dental_prescription_625_crop_8.jpg',
#  'prescription_Gyne_18_crop_7.jpg',
#  'Dental_prescription_543_crop_5.jpg',
#  'Neurology_prescription_64_crop_6.jpg',
#  'prescription_Gyne_462_crop_2.jpg',
#  'prescription_Gyne_403_crop_0.jpg',
#  'prescription_Gyne_81_crop_4.jpg',
#  'Dental_prescription_625_crop_13.jpg',
#  'prescription_Gyne_478_crop_1.jpg',
#  'prescription_Gyne_156_crop_14.jpg',
#  'Neurology_prescription_62_crop_2.jpg',
#  'prescription_Gyne_470_crop_4.jpg',
#  'prescription_Gyne_59_crop_1.jpg',
#  'prescription_Gyne_134_crop_16.jpg',
#  'prescription_Gyne_354_crop_0.jpg',
#  'prescription_opth_230_crop_4.jpg',
#  'Dental_prescription_617 (1)_crop_10.jpg',
#  'prescription_Gyne_408_crop_5.jpg',
#  'prescription_Gyne_81_crop_9.jpg',
#  'Dental_prescription_557_crop_6.jpg',
#  'prescription_Gyne_98_crop_2.jpg',
#  'Dental_prescription_620 (1)_crop_7.jpg',
#  'Dental_prescription_539_crop_9.jpg',
#  'Dental_prescription_609_crop_4.jpg',
#  'prescription_Gyne_59_crop_11.jpg',
#  'Dental_prescription_489_crop_1.jpg',
#  'prescription_Gyne_2_crop_9.jpg',
#  'Dental_prescription_625_crop_14.jpg',
#  'Dental_prescription_609_crop_10.jpg',
#  'prescription_opth_167_crop_13.jpg',
#  'prescription_Gyne_389_crop_11.jpg',
#  'prescription_opth_261_crop_15.jpg',
#  'Neurology_prescription_76_crop_0.jpg',
#  'Neurology_prescription_63_crop_3.jpg',
#  'prescription_Gyne_343_crop_9.jpg',
#  'prescription_opth_261_crop_7.jpg',
#  'prescription_Gyne_2_crop_4.jpg',
#  'Neurology_prescription_56_crop_8.jpg',
#  'prescription_Gyne_18_crop_24.jpg',
#  'Dental_prescription_630 (1)_crop_1.jpg',
#  'prescription_Gyne_478_crop_9.jpg',
#  'prescription_Gyne_475_crop_6.jpg',
#  'prescription_opth_161_crop_4.jpg',
#  'Neurology_prescription_70_crop_3.jpg',
#  'Dental_prescription_543_crop_2.jpg',
#  'prescription_Gyne_393_crop_9.jpg',
#  'prescription_Gyne_478_crop_5.jpg',
#  'prescription_Gyne_18_crop_9.jpg',
#  'Dental_prescription_631_crop_0.jpg',
#  'Dental_prescription_609_crop_3.jpg',
#  'prescription_Gyne_382_crop_14.jpg',
#  'Neurology_prescription_67_crop_11.jpg',
#  'prescription_Gyne_402_crop_6.jpg',
#  'Neurology_prescription_70_crop_7.jpg',
#  'prescription_Gyne_117_crop_4.jpg',
#  'Neurology_prescription_60_crop_3.jpg',
#  'prescription_opth_161_crop_6.jpg',
#  'prescription_Gyne_402_crop_20.jpg',
#  'Dental_prescription_615_crop_6.jpg',
#  'prescription_opth_193_crop_6.jpg',
#  'prescription_Gyne_434_crop_2.jpg',
#  'Neurology_prescription_73_crop_4.jpg',
#  'Dental_prescription_488_crop_4.jpg',
#  'Dental_prescription_615_crop_12.jpg',
#  'prescription_Gyne_393_crop_18.jpg',
#  'prescription_Gyne_393_crop_3.jpg',
#  'prescription_Gyne_424_crop_13.jpg',
#  'Dental_prescription_542_crop_14.jpg',
#  'prescription_Gyne_424_crop_3.jpg',
#  'prescription_Gyne_402_crop_21.jpg',
#  'Dental_prescription_482_crop_1.jpg',
#  'prescription_Gyne_19_crop_11.jpg',
#  'Dental_prescription_557_crop_7.jpg',
#  'prescription_Gyne_430_crop_11.jpg',
#  'prescription_Gyne_354_crop_3.jpg',
#  'Neurology_prescription_58_crop_0.jpg',
#  'prescription_Gyne_322_crop_1.jpg',
#  'prescription_Gyne_403_crop_2.jpg',
#  'Dental_prescription_539_crop_11.jpg',
#  'prescription_Gyne_85_crop_14.jpg',
#  'prescription_opth_198_crop_5.jpg',
#  'Dental_prescription_615_crop_1.jpg',
#  'prescription_Gyne_444_crop_3.jpg',
#  'Dental_prescription_619 (1)_crop_11.jpg',
#  'prescription_Gyne_382_crop_11.jpg',
#  'prescription_Gyne_393_crop_11.jpg',
#  'prescription_Gyne_322_crop_4.jpg',
#  'Neurology_prescription_67_crop_3.jpg',
#  'Dental_prescription_539_crop_1.jpg',
#  'prescription_Gyne_358_crop_2.jpg',
#  'prescription_Gyne_403_crop_9.jpg',
#  'prescription_Gyne_38_crop_3.jpg',
#  'prescription_Gyne_406_crop_4.jpg',
#  'Dental_prescription_489_crop_6.jpg',
#  'prescription_Gyne_475_crop_0.jpg',
#  'prescription_Gyne_470_crop_5.jpg',
#  'prescription_Gyne_424_crop_2.jpg',
#  'Dental_prescription_609_crop_2.jpg',
#  'prescription_Gyne_117_crop_1.jpg',
#  'prescription_opth_167_crop_7.jpg',
#  'prescription_Gyne_337_crop_9.jpg',
#  'prescription_Gyne_326_crop_12.jpg',
#  'prescription_Gyne_382_crop_10.jpg',
#  'prescription_Gyne_2_crop_5.jpg',
#  'Neurology_prescription_69_crop_11.jpg',
#  'Dental_prescription_605 (1)_crop_6.jpg',
#  'prescription_Gyne_326_crop_10.jpg',
#  'Dental_prescription_611_crop_2.jpg',
#  'prescription_opth_230_crop_8.jpg',
#  'Dental_prescription_562_crop_2.jpg',
#  'prescription_Gyne_416_crop_3.jpg',
#  'prescription_Gyne_18_crop_3.jpg',
#  'Neurology_prescription_61_crop_4.jpg',
#  'Neurology_prescription_59_crop_3.jpg',
#  'prescription_opth_167_crop_6.jpg',
#  'Neurology_prescription_59_crop_0.jpg',
#  'prescription_Gyne_18_crop_21.jpg',
#  'Neurology_prescription_75_crop_1.jpg',
#  'prescription_Gyne_62_crop_12.jpg',
#  'prescription_Gyne_156_crop_8.jpg',
#  'prescription_Gyne_19_crop_3.jpg',
#  'prescription_Gyne_18_crop_15.jpg',
#  'prescription_Gyne_19_crop_14.jpg',
#  'prescription_Gyne_145_crop_9.jpg',
#  'prescription_Gyne_402_crop_1.jpg',
#  'Neurology_prescription_67_crop_7.jpg',
#  'Neurology_prescription_63_crop_0.jpg',
#  'Neurology_prescription_61_crop_1.jpg',
#  'prescription_Gyne_149_crop_0.jpg',
#  'prescription_opth_261_crop_8.jpg',
#  'Neurology_prescription_70_crop_11.jpg',
#  'prescription_Gyne_9_crop_5.jpg',
#  'prescription_opth_202_crop_12.jpg',
#  'prescription_Gyne_141_crop_19.jpg',
#  'prescription_Gyne_358_crop_0.jpg',
#  'prescription_Gyne_358_crop_9.jpg',
#  'Neurology_prescription_72_crop_8.jpg',
#  'prescription_Gyne_335_crop_10.jpg',
#  'prescription_Gyne_403_crop_3.jpg',
#  'Dental_prescription_602 (1)_crop_4.jpg',
#  'Dental_prescription_566_crop_2.jpg',
#  'Dental_prescription_557_crop_4.jpg',
#  'Dental_prescription_615_crop_9.jpg',
#  'Neurology_prescription_66_crop_1.jpg',
#  'prescription_Gyne_382_crop_4.jpg',
#  'prescription_Gyne_62_crop_0.jpg',
#  'Dental_prescription_611_crop_10.jpg',
#  'prescription_Gyne_393_crop_4.jpg',
#  'Neurology_prescription_79_crop_4.jpg',
#  'prescription_opth_198_crop_10.jpg',
#  'prescription_Gyne_406_crop_13.jpg',
#  'Dental_prescription_621_crop_7.jpg',
#  'Neurology_prescription_60_crop_5.jpg',
#  'Dental_prescription_617 (1)_crop_13.jpg',
#  'Dental_prescription_488_crop_8.jpg',
#  'Neurology_prescription_76_crop_3.jpg',
#  'Dental_prescription_566_crop_5.jpg',
#  'prescription_Gyne_145_crop_6.jpg',
#  'Neurology_prescription_67_crop_12.jpg',
#  'prescription_Gyne_435_crop_9.jpg',
#  'prescription_opth_261_crop_21.jpg',
#  'Dental_prescription_612_crop_1.jpg',
#  'prescription_Gyne_97_crop_5.jpg',
#  'prescription_Gyne_156_crop_16.jpg',
#  'Neurology_prescription_62_crop_0.jpg',
#  'Neurology_prescription_80_crop_0.jpg',
#  'Dental_prescription_625_crop_4.jpg',
#  'Dental_prescription_609_crop_15.jpg',
#  'prescription_Gyne_406_crop_11.jpg',
#  'prescription_Gyne_337_crop_4.jpg',
#  'prescription_Gyne_141_crop_1.jpg',
#  'Dental_prescription_630 (1)_crop_3.jpg',
#  'prescription_Gyne_145_crop_7.jpg',
#  'Dental_prescription_557_crop_11.jpg',
#  'Dental_prescription_603_crop_2.jpg',
#  'Dental_prescription_539_crop_7.jpg',
#  'prescription_Gyne_19_crop_13.jpg',
#  'prescription_opth_261_crop_6.jpg',
#  'prescription_Gyne_337_crop_10.jpg',
#  'prescription_Gyne_434_crop_12.jpg',
#  'prescription_Gyne_478_crop_8.jpg',
#  'Dental_prescription_619_crop_2.jpg',
#  'prescription_opth_161_crop_17.jpg',
#  'prescription_Gyne_393_crop_8.jpg',
#  'Dental_prescription_611 (1)_crop_6.jpg',
#  'prescription_opth_198_crop_1.jpg',
#  'prescription_Gyne_38_crop_0.jpg',
#  'Neurology_prescription_75_crop_9.jpg',
#  'Dental_prescription_542_crop_0.jpg',
#  'Dental_prescription_566_crop_0.jpg',
#  'prescription_opth_202_crop_9.jpg',
#  'Dental_prescription_488_crop_6.jpg',
#  'Neurology_prescription_56_crop_3.jpg',
#  'prescription_Gyne_358_crop_13.jpg',
#  'prescription_opth_161_crop_22.jpg',
#  'prescription_Gyne_337_crop_1.jpg',
#  'Neurology_prescription_58_crop_9.jpg',
#  'Neurology_prescription_56_crop_1.jpg',
#  'prescription_Gyne_156_crop_13.jpg',
#  'Neurology_prescription_75_crop_10.jpg',
#  'prescription_Gyne_478_crop_13.jpg',
#  'prescription_Gyne_430_crop_0.jpg',
#  'Dental_prescription_620 (1)_crop_0.jpg',
#  'Neurology_prescription_75_crop_5.jpg',
#  'Dental_prescription_619 (1)_crop_9.jpg',
#  'prescription_Gyne_134_crop_8.jpg',
#  'Neurology_prescription_59_crop_7.jpg',
#  'prescription_Gyne_156_crop_17.jpg',
#  'prescription_Gyne_382_crop_13.jpg',
#  'Dental_prescription_617 (1)_crop_12.jpg',
#  'prescription_Gyne_478_crop_2.jpg',
#  'prescription_Gyne_419_crop_11.jpg',
#  'Dental_prescription_620 (1)_crop_3.jpg',
#  'prescription_Gyne_434_crop_9.jpg',
#  'prescription_Gyne_478_crop_7.jpg',
#  'prescription_Gyne_343_crop_8.jpg',
#  'prescription_Gyne_406_crop_10.jpg',
#  'prescription_opth_193_crop_0.jpg',
#  'prescription_opth_261_crop_1.jpg',
#  'prescription_Gyne_382_crop_15.jpg',
#  'Dental_prescription_539_crop_10.jpg',
#  'prescription_Gyne_322_crop_7.jpg',
#  'prescription_Gyne_416_crop_4.jpg',
#  'Neurology_prescription_64_crop_10.jpg',
#  'prescription_Gyne_434_crop_4.jpg',
#  'Neurology_prescription_68_crop_1.jpg',
#  'prescription_Gyne_85_crop_6.jpg',
#  'Dental_prescription_544_crop_3.jpg',
#  'Dental_prescription_625_crop_2.jpg',
#  'Dental_prescription_557_crop_5.jpg',
#  'prescription_Gyne_145_crop_2.jpg',
#  'Dental_prescription_620 (1)_crop_4.jpg',
#  'Neurology_prescription_73_crop_8.jpg',
#  'prescription_Gyne_141_crop_17.jpg',
#  'prescription_Gyne_334_crop_11.jpg',
#  'Dental_prescription_542_crop_12.jpg',
#  'Neurology_prescription_80_crop_4.jpg',
#  'prescription_Gyne_81_crop_5.jpg',
#  'prescription_Gyne_354_crop_8.jpg',
#  'Dental_prescription_620 (1)_crop_10.jpg',
#  'Dental_prescription_611 (1)_crop_5.jpg',
#  'prescription_Gyne_62_crop_5.jpg',
#  'Dental_prescription_617 (1)_crop_4.jpg',
#  'prescription_Gyne_59_crop_0.jpg',
#  'prescription_Gyne_335_crop_7.jpg',
#  'Neurology_prescription_62_crop_7.jpg',
#  'Neurology_prescription_75_crop_4.jpg',
#  'Dental_prescription_557_crop_2.jpg',
#  'prescription_Gyne_19_crop_7.jpg',
#  'prescription_Gyne_85_crop_12.jpg',
#  'prescription_Gyne_408_crop_7.jpg',
#  'prescription_Gyne_382_crop_16.jpg',
#  'prescription_Gyne_425_crop_4.jpg',
#  'Dental_prescription_617 (1)_crop_2.jpg',
#  'prescription_Gyne_141_crop_5.jpg',
#  'Neurology_prescription_70_crop_0.jpg',
#  'prescription_Gyne_2_crop_2.jpg',
#  'Dental_prescription_489_crop_0.jpg',
#  'prescription_Gyne_406_crop_8.jpg',
#  'prescription_Gyne_117_crop_0.jpg',
#  'prescription_Gyne_335_crop_16.jpg',
#  'prescription_Gyne_430_crop_7.jpg',
#  'Neurology_prescription_70_crop_4.jpg',
#  'Dental_prescription_630 (1)_crop_4.jpg',
#  'Dental_prescription_539_crop_5.jpg',
#  'prescription_Gyne_18_crop_10.jpg',
#  'prescription_Gyne_326_crop_0.jpg',
#  'Neurology_prescription_60_crop_0.jpg',
#  'prescription_Gyne_81_crop_14.jpg',
#  'Neurology_prescription_62_crop_11.jpg',
#  'prescription_Gyne_382_crop_17.jpg',
#  'prescription_Gyne_419_crop_7.jpg',
#  'prescription_Gyne_38_crop_9.jpg',
#  'Neurology_prescription_60_crop_6.jpg',
#  'Neurology_prescription_59_crop_1.jpg',
#  'prescription_Gyne_337_crop_12.jpg',
#  'prescription_Gyne_37_crop_3.jpg',
#  'Neurology_prescription_64_crop_7.jpg',
#  'prescription_Gyne_81_crop_2.jpg',
#  'Neurology_prescription_79_crop_9.jpg',
#  'Neurology_prescription_66_crop_3.jpg',
#  'Dental_prescription_488_crop_7.jpg',
#  'Dental_prescription_539_crop_8.jpg',
#  'prescription_Gyne_326_crop_9.jpg',
#  'Neurology_prescription_70_crop_9.jpg',
#  'prescription_Gyne_117_crop_3.jpg',
#  'prescription_Gyne_408_crop_0.jpg',
#  'prescription_opth_197_crop_3.jpg',
#  'prescription_Gyne_134_crop_18.jpg',
#  'prescription_Gyne_97_crop_7.jpg',
#  'prescription_Gyne_85_crop_13.jpg',
#  'Dental_prescription_620 (1)_crop_9.jpg',
#  'prescription_Gyne_408_crop_4.jpg',
#  'prescription_Gyne_156_crop_0.jpg',
#  'Dental_prescription_543_crop_1.jpg',
#  'Neurology_prescription_69_crop_7.jpg',
#  'Neurology_prescription_74_crop_4.jpg',
#  'prescription_Gyne_18_crop_18.jpg',
#  'prescription_Gyne_382_crop_12.jpg',
#  'Dental_prescription_602 (1)_crop_5.jpg',
#  'Dental_prescription_612 (1)_crop_2.jpg',
#  'Dental_prescription_612 (1)_crop_0.jpg',
#  'prescription_Gyne_85_crop_18.jpg',
#  'prescription_Gyne_337_crop_2.jpg',
#  'Neurology_prescription_75_crop_8.jpg',
#  'prescription_Gyne_322_crop_3.jpg',
#  'prescription_opth_197_crop_5.jpg',
#  'Neurology_prescription_74_crop_6.jpg',
#  'Neurology_prescription_57_crop_6.jpg',
#  'prescription_Gyne_85_crop_8.jpg',
#  'prescription_Gyne_37_crop_1.jpg',
#  'Neurology_prescription_74_crop_0.jpg',
#  'prescription_Gyne_404_crop_2.jpg',
#  'prescription_Gyne_335_crop_14.jpg',
#  'Dental_prescription_611_crop_8.jpg',
#  'prescription_Gyne_402_crop_16.jpg',
#  'Dental_prescription_617 (1)_crop_5.jpg',
#  'prescription_Gyne_389_crop_1.jpg',
#  'prescription_Gyne_38_crop_2.jpg',
#  'prescription_Gyne_478_crop_10.jpg',
#  'prescription_Gyne_393_crop_15.jpg',
#  'Dental_prescription_543_crop_0.jpg',
#  'Dental_prescription_620 (1)_crop_5.jpg',
#  'prescription_Gyne_402_crop_12.jpg',
#  'prescription_Gyne_334_crop_4.jpg',
#  'Dental_prescription_539_crop_2.jpg',
#  'Dental_prescription_611 (1)_crop_8.jpg',
#  'prescription_Gyne_141_crop_8.jpg',
#  'prescription_Gyne_335_crop_8.jpg',
#  'prescription_Gyne_406_crop_2.jpg',
#  'Neurology_prescription_56_crop_0.jpg',
#  'prescription_Gyne_389_crop_4.jpg',
#  'prescription_Gyne_358_crop_16.jpg',
#  'prescription_opth_261_crop_10.jpg',
#  'prescription_Gyne_402_crop_9.jpg',
#  'prescription_Gyne_134_crop_14.jpg',
#  'prescription_Gyne_419_crop_2.jpg',
#  'Dental_prescription_615_crop_3.jpg',
#  'prescription_opth_261_crop_25.jpg',
#  'prescription_Gyne_416_crop_5.jpg',
#  'prescription_Gyne_117_crop_5.jpg',
#  'Neurology_prescription_64_crop_4.jpg',
#  'prescription_Gyne_406_crop_12.jpg',
#  'Neurology_prescription_78_crop_3.jpg',
#  'prescription_Gyne_419_crop_3.jpg',
#  'Dental_prescription_607 (1)_crop_5.jpg',
#  'prescription_Gyne_475_crop_8.jpg',
#  'Neurology_prescription_69_crop_3.jpg',
#  'prescription_Gyne_358_crop_11.jpg',
#  'prescription_Gyne_2_crop_7.jpg',
#  'prescription_Gyne_59_crop_12.jpg',
#  'Neurology_prescription_79_crop_2.jpg',
#  'prescription_Gyne_408_crop_1.jpg',
#  'Neurology_prescription_78_crop_2.jpg',
#  'prescription_opth_198_crop_23.jpg',
#  'prescription_Gyne_361_crop_0.jpg',
#  'prescription_Gyne_434_crop_0.jpg',
#  'Dental_prescription_612 (1)_crop_3.jpg',
#  'prescription_Gyne_389_crop_5.jpg',
#  'Neurology_prescription_58_crop_3.jpg',
#  'prescription_Gyne_393_crop_20.jpg',
#  'prescription_Gyne_403_crop_4.jpg',
#  'prescription_Gyne_402_crop_15.jpg',
#  'prescription_Gyne_447_crop_9.jpg',
#  'Dental_prescription_557_crop_9.jpg',
#  'prescription_Gyne_435_crop_4.jpg',
#  'prescription_Gyne_334_crop_10.jpg',
#  'Neurology_prescription_77_crop_6.jpg',
#  'prescription_Gyne_358_crop_14.jpg',
#  'Dental_prescription_621_crop_5.jpg',
#  'prescription_Gyne_37_crop_0.jpg',
#  'Neurology_prescription_63_crop_7.jpg',
#  'prescription_Gyne_343_crop_6.jpg',
#  'prescription_Gyne_447_crop_1.jpg',
#  'prescription_Gyne_435_crop_11.jpg',
#  'Neurology_prescription_70_crop_8.jpg',
#  'prescription_Gyne_403_crop_10.jpg',
#  'prescription_Gyne_447_crop_13.jpg',
#  'Dental_prescription_539_crop_0.jpg',
#  'prescription_Gyne_334_crop_14.jpg',
#  'prescription_Gyne_424_crop_4.jpg',
#  'Dental_prescription_544_crop_4.jpg',
#  'Neurology_prescription_61_crop_5.jpg',
#  'prescription_Gyne_19_crop_4.jpg',
#  'prescription_Gyne_98_crop_1.jpg',
#  'prescription_Gyne_85_crop_4.jpg',
#  'Neurology_prescription_72_crop_0.jpg',
#  'Dental_prescription_482_crop_4.jpg',
#  'Neurology_prescription_62_crop_4.jpg',
#  'prescription_Gyne_393_crop_6.jpg',
#  'prescription_Gyne_403_crop_12.jpg',
#  'prescription_Gyne_424_crop_1.jpg',
#  'prescription_Gyne_85_crop_10.jpg',
#  'Neurology_prescription_80_crop_2.jpg',
#  'prescription_Gyne_343_crop_1.jpg',
#  'prescription_Gyne_424_crop_10.jpg',
#  'Dental_prescription_542_crop_10.jpg',
#  'Dental_prescription_617 (1)_crop_6.jpg',
#  'prescription_opth_167_crop_4.jpg',
#  'prescription_Gyne_18_crop_19.jpg',
#  'Dental_prescription_485_crop_2.jpg',
#  'prescription_Gyne_97_crop_1.jpg',
#  'Dental_prescription_543_crop_6.jpg',
#  'prescription_Gyne_425_crop_8.jpg',
#  'prescription_Gyne_447_crop_11.jpg',
#  'prescription_opth_193_crop_2.jpg',
#  'Dental_prescription_615_crop_2.jpg',
#  'Dental_prescription_542_crop_18.jpg',
#  'prescription_Gyne_430_crop_10.jpg',
#  'Neurology_prescription_59_crop_5.jpg',
#  'prescription_opth_161_crop_7.jpg',
#  'prescription_Gyne_38_crop_1.jpg',
#  'prescription_Gyne_18_crop_22.jpg',
#  'Dental_prescription_566_crop_1.jpg',
#  'Dental_prescription_542_crop_4.jpg',
#  'Neurology_prescription_57_crop_0.jpg',
#  'Neurology_prescription_69_crop_8.jpg',
#  'Dental_prescription_612_crop_4.jpg',
#  'Neurology_prescription_77_crop_7.jpg',
#  'prescription_Gyne_358_crop_12.jpg',
#  'prescription_opth_202_crop_10.jpg',
#  'prescription_Gyne_406_crop_1.jpg',
#  'prescription_Gyne_419_crop_0.jpg',
#  'prescription_Gyne_2_crop_14.jpg',
#  'prescription_opth_193_crop_3.jpg',
#  'prescription_Gyne_322_crop_8.jpg',
#  'prescription_Gyne_37_crop_2.jpg',
#  'prescription_Gyne_424_crop_6.jpg',
#  'prescription_Gyne_81_crop_13.jpg',
#  'prescription_Gyne_358_crop_5.jpg',
#  'prescription_Gyne_403_crop_5.jpg',
#  'prescription_opth_167_crop_0.jpg',
#  'prescription_Gyne_156_crop_2.jpg',
#  'Dental_prescription_489_crop_5.jpg',
#  'prescription_Gyne_97_crop_8.jpg',
#  'prescription_Gyne_403_crop_6.jpg',
#  'prescription_Gyne_419_crop_5.jpg',
#  'prescription_Gyne_149_crop_1.jpg',
#  'prescription_opth_198_crop_0.jpg',
#  'Neurology_prescription_69_crop_5.jpg',
#  'Neurology_prescription_67_crop_8.jpg',
#  'prescription_Gyne_337_crop_0.jpg',
#  'Dental_prescription_542_crop_3.jpg',
#  'prescription_opth_198_crop_4.jpg',
#  'prescription_Gyne_13_crop_2.jpg',
#  'prescription_Gyne_435_crop_0.jpg',
#  'Dental_prescription_617 (1)_crop_9.jpg',
#  'prescription_Gyne_322_crop_5.jpg',
#  'prescription_Gyne_98_crop_0.jpg',
#  'prescription_Gyne_19_crop_1.jpg',
#  'Dental_prescription_619 (1)_crop_5.jpg',
#  'Dental_prescription_619 (1)_crop_4.jpg',
#  'prescription_Gyne_335_crop_20.jpg',
#  'Neurology_prescription_58_crop_2.jpg',
#  'prescription_opth_261_crop_16.jpg',
#  'prescription_Gyne_430_crop_13.jpg',
#  'prescription_Gyne_444_crop_5.jpg',
#  'prescription_opth_193_crop_5.jpg',
#  'prescription_opth_193_crop_1.jpg',
#  'prescription_Gyne_156_crop_3.jpg',
#  'prescription_Gyne_335_crop_9.jpg',
#  'Dental_prescription_539_crop_13.jpg',
#  'prescription_opth_261_crop_18.jpg',
#  'prescription_opth_202_crop_17.jpg',
#  'prescription_opth_197_crop_0.jpg',
#  'Dental_prescription_539_crop_12.jpg',
#  'prescription_Gyne_134_crop_6.jpg',
#  'prescription_Gyne_145_crop_8.jpg',
#  'prescription_Gyne_134_crop_17.jpg',
#  'prescription_Gyne_141_crop_16.jpg',
#  'prescription_Gyne_59_crop_9.jpg',
#  'Neurology_prescription_62_crop_6.jpg',
#  'prescription_Gyne_419_crop_8.jpg',
#  'Neurology_prescription_60_crop_8.jpg',
#  'Dental_prescription_612 (1)_crop_1.jpg',
#  'prescription_Gyne_334_crop_6.jpg',
#  'prescription_opth_202_crop_3.jpg',
#  'prescription_Gyne_335_crop_15.jpg',
#  'Neurology_prescription_71_crop_0.jpg',
#  'Neurology_prescription_61_crop_0.jpg',
#  'prescription_opth_261_crop_9.jpg',
#  'Dental_prescription_625_crop_3.jpg',
#  'Neurology_prescription_60_crop_7.jpg',
#  'prescription_Gyne_478_crop_14.jpg',
#  'prescription_Gyne_444_crop_6.jpg',
#  'Dental_prescription_611 (1)_crop_3.jpg',
#  'Neurology_prescription_65_crop_0.jpg',
#  'prescription_Gyne_444_crop_4.jpg',
#  'prescription_opth_193_crop_16.jpg',
#  'prescription_Gyne_141_crop_0.jpg',
#  'Dental_prescription_621_crop_4.jpg',
#  'Dental_prescription_619_crop_3.jpg',
#  'prescription_opth_261_crop_5.jpg',
#  'Dental_prescription_619 (1)_crop_2.jpg',
#  'Dental_prescription_609_crop_13.jpg',
#  'prescription_Gyne_393_crop_13.jpg',
#  'prescription_Gyne_425_crop_0.jpg',
#  'prescription_Gyne_430_crop_12.jpg',
#  'prescription_Gyne_354_crop_2.jpg',
#  'Neurology_prescription_77_crop_4.jpg',
#  'prescription_opth_197_crop_4.jpg',
#  'prescription_Gyne_447_crop_2.jpg',
#  'prescription_Gyne_447_crop_8.jpg',
#  'prescription_Gyne_404_crop_1.jpg',
#  'prescription_opth_198_crop_3.jpg',
#  'Dental_prescription_482_crop_3.jpg',
#  'prescription_Gyne_156_crop_10.jpg',
#  'prescription_Gyne_62_crop_13.jpg',
#  'prescription_Gyne_334_crop_13.jpg',
#  'prescription_Gyne_389_crop_2.jpg',
#  'Dental_prescription_615_crop_0.jpg',
#  'Dental_prescription_630 (1)_crop_2.jpg',
#  'prescription_opth_161_crop_10.jpg',
#  'Neurology_prescription_59_crop_6.jpg',
#  'Dental_prescription_617 (1)_crop_11.jpg',
#  'prescription_Gyne_430_crop_14.jpg',
#  'prescription_Gyne_59_crop_15.jpg',
#  'prescription_Gyne_18_crop_2.jpg',
#  'prescription_opth_193_crop_9.jpg',
#  'prescription_Gyne_134_crop_5.jpg',
#  'prescription_Gyne_19_crop_16.jpg',
#  'Neurology_prescription_57_crop_1.jpg',
#  'prescription_Gyne_434_crop_15.jpg',
#  'Neurology_prescription_73_crop_6.jpg',
#  'prescription_Gyne_18_crop_8.jpg',
#  'Neurology_prescription_64_crop_2.jpg',
#  'prescription_Gyne_393_crop_10.jpg',
#  'prescription_Gyne_419_crop_9.jpg',
#  'prescription_Gyne_354_crop_1.jpg',
#  'prescription_Gyne_19_crop_5.jpg',
#  'prescription_opth_261_crop_20.jpg',
#  'Dental_prescription_625_crop_16.jpg',
#  'prescription_Gyne_337_crop_7.jpg',
#  'prescription_Gyne_322_crop_9.jpg',
#  'Neurology_prescription_70_crop_2.jpg',
#  'prescription_Gyne_81_crop_7.jpg',
#  'Dental_prescription_611_crop_5.jpg',
#  'Neurology_prescription_58_crop_6.jpg',
#  'Neurology_prescription_68_crop_0.jpg',
#  'Dental_prescription_611_crop_6.jpg',
#  'Dental_prescription_619_crop_8.jpg',
#  'Dental_prescription_609_crop_8.jpg',
#  'Dental_prescription_615_crop_8.jpg',
#  'Dental_prescription_543_crop_4.jpg',
#  'prescription_opth_202_crop_13.jpg',
#  'Dental_prescription_621_crop_6.jpg',
#  'prescription_opth_230_crop_2.jpg',
#  'prescription_Gyne_444_crop_2.jpg',
#  'Dental_prescription_539_crop_4.jpg',
#  'prescription_opth_198_crop_11.jpg',
#  'prescription_Gyne_326_crop_3.jpg',
#  'Neurology_prescription_71_crop_3.jpg',
#  'prescription_Gyne_354_crop_7.jpg',
#  'prescription_Gyne_141_crop_2.jpg',
#  'prescription_Gyne_81_crop_1.jpg',
#  'prescription_Gyne_62_crop_11.jpg',
#  'prescription_opth_161_crop_14.jpg',
#  'prescription_Gyne_393_crop_0.jpg',
#  'Dental_prescription_625_crop_15.jpg',
#  'prescription_Gyne_434_crop_3.jpg',
#  'Dental_prescription_568_crop_5.jpg',
#  'prescription_opth_167_crop_2.jpg',
#  'Neurology_prescription_67_crop_2.jpg',
#  'prescription_Gyne_335_crop_4.jpg',
#  'prescription_Gyne_403_crop_1.jpg',
#  'prescription_opth_193_crop_14.jpg',
#  'Neurology_prescription_69_crop_12.jpg',
#  'Dental_prescription_485_crop_0.jpg',
#  'prescription_Gyne_419_crop_13.jpg',
#  'prescription_Gyne_478_crop_6.jpg',
#  'Neurology_prescription_57_crop_9.jpg',
#  'Dental_prescription_607 (1)_crop_2.jpg',
#  'prescription_opth_161_crop_2.jpg',
#  'prescription_Gyne_434_crop_10.jpg',
#  'prescription_opth_261_crop_24.jpg',
#  'prescription_Gyne_38_crop_10.jpg',
#  'prescription_opth_161_crop_3.jpg',
#  'Neurology_prescription_71_crop_1.jpg',
#  'Neurology_prescription_70_crop_10.jpg',
#  'Dental_prescription_609_crop_7.jpg',
#  'Neurology_prescription_65_crop_2.jpg',
#  'Dental_prescription_489_crop_4.jpg',
#  'prescription_Gyne_18_crop_12.jpg',
#  'prescription_Gyne_322_crop_11.jpg',
#  'Dental_prescription_611 (1)_crop_0.jpg',
#  'Dental_prescription_488_crop_3.jpg',
#  'prescription_opth_202_crop_1.jpg',
#  'prescription_Gyne_326_crop_11.jpg',
#  'prescription_Gyne_334_crop_16.jpg',
#  'Neurology_prescription_74_crop_7.jpg',
#  'prescription_Gyne_38_crop_4.jpg',
#  'Dental_prescription_620 (1)_crop_1.jpg',
#  'prescription_Gyne_19_crop_2.jpg',
#  'Dental_prescription_542_crop_13.jpg',
#  'prescription_Gyne_19_crop_17.jpg',
#  'Dental_prescription_542_crop_6.jpg',
#  'Neurology_prescription_56_crop_4.jpg',
#  'Neurology_prescription_70_crop_1.jpg',
#  'prescription_Gyne_81_crop_6.jpg',
#  'Neurology_prescription_79_crop_10.jpg',
#  'prescription_Gyne_85_crop_11.jpg',
#  'Neurology_prescription_72_crop_2.jpg',
#  'prescription_opth_202_crop_11.jpg',
#  'Dental_prescription_621_crop_1.jpg',
#  'prescription_opth_261_crop_14.jpg',
#  'prescription_Gyne_141_crop_20.jpg',
#  'prescription_Gyne_335_crop_2.jpg',
#  'prescription_opth_167_crop_3.jpg',
#  'prescription_Gyne_406_crop_5.jpg',
#  'Dental_prescription_602 (1)_crop_2.jpg',
#  'Neurology_prescription_76_crop_1.jpg',
#  'Neurology_prescription_62_crop_10.jpg',
#  'Neurology_prescription_58_crop_1.jpg',
#  'prescription_Gyne_18_crop_16.jpg',
#  'Neurology_prescription_63_crop_1.jpg',
#  'prescription_Gyne_145_crop_0.jpg',
#  'Dental_prescription_543_crop_8.jpg',
#  'Dental_prescription_566_crop_4.jpg',
#  'prescription_Gyne_337_crop_6.jpg',
#  'Dental_prescription_603_crop_1.jpg',
#  'prescription_opth_202_crop_7.jpg',
#  'prescription_Gyne_141_crop_13.jpg',
#  'prescription_Gyne_447_crop_10.jpg',
#  'Dental_prescription_566_crop_3.jpg',
#  'prescription_Gyne_447_crop_4.jpg',
#  'Dental_prescription_544_crop_0.jpg',
#  'prescription_Gyne_18_crop_20.jpg',
#  'prescription_opth_197_crop_6.jpg',
#  'prescription_Gyne_156_crop_12.jpg',
#  'prescription_Gyne_447_crop_6.jpg',
#  'Neurology_prescription_72_crop_7.jpg',
#  'prescription_Gyne_334_crop_2.jpg',
#  'Dental_prescription_542_crop_8.jpg',
#  'prescription_Gyne_382_crop_3.jpg',
#  'Neurology_prescription_62_crop_5.jpg',
#  'prescription_opth_161_crop_1.jpg',
#  'Dental_prescription_612_crop_0.jpg',
#  'prescription_opth_261_crop_2.jpg',
#  'prescription_Gyne_134_crop_13.jpg',
#  'prescription_Gyne_382_crop_8.jpg',
#  'prescription_Gyne_402_crop_8.jpg',
#  'prescription_Gyne_335_crop_6.jpg',
#  'prescription_Gyne_475_crop_7.jpg',
#  'prescription_Gyne_354_crop_5.jpg',
#  'prescription_Gyne_141_crop_15.jpg',
#  'prescription_Gyne_402_crop_3.jpg',
#  'prescription_Gyne_430_crop_2.jpg',
#  'Dental_prescription_609_crop_14.jpg',
#  'prescription_Gyne_430_crop_6.jpg',
#  'Dental_prescription_619_crop_5.jpg',
#  'Neurology_prescription_63_crop_10.jpg',
#  'prescription_Gyne_145_crop_3.jpg',
#  'prescription_opth_193_crop_4.jpg',
#  'prescription_opth_167_crop_1.jpg',
#  'Dental_prescription_603_crop_0.jpg',
#  'prescription_opth_167_crop_11.jpg',
#  'prescription_opth_161_crop_20.jpg',
#  'prescription_Gyne_149_crop_3.jpg',
#  'prescription_opth_198_crop_12.jpg',
#  'prescription_Gyne_406_crop_9.jpg',
#  'Dental_prescription_612 (1)_crop_4.jpg',
#  'prescription_opth_261_crop_19.jpg',
#  'Neurology_prescription_58_crop_7.jpg',
#  'Dental_prescription_615_crop_4.jpg',
#  'Dental_prescription_488_crop_5.jpg',
#  'prescription_opth_161_crop_0.jpg',
#  'prescription_Gyne_434_crop_14.jpg',
#  'prescription_opth_230_crop_3.jpg',
#  'prescription_Gyne_18_crop_13.jpg',
#  'prescription_Gyne_18_crop_5.jpg',
#  'Dental_prescription_485_crop_1.jpg',
#  'Neurology_prescription_67_crop_9.jpg',
#  'prescription_Gyne_134_crop_9.jpg',
#  'prescription_Gyne_141_crop_4.jpg',
#  'prescription_Gyne_326_crop_7.jpg',
#  'prescription_Gyne_134_crop_11.jpg',
#  'Neurology_prescription_72_crop_4.jpg',
#  'prescription_Gyne_322_crop_14.jpg',
#  'prescription_Gyne_358_crop_3.jpg',
#  'prescription_Gyne_406_crop_14.jpg',
#  'Dental_prescription_568_crop_1.jpg',
#  'prescription_Gyne_424_crop_8.jpg',
#  'prescription_opth_261_crop_0.jpg',
#  'Dental_prescription_607 (1)_crop_4.jpg',
#  'Neurology_prescription_78_crop_1.jpg',
#  'prescription_Gyne_402_crop_0.jpg',
#  'prescription_opth_161_crop_16.jpg',
#  'prescription_Gyne_435_crop_10.jpg',
#  'prescription_Gyne_470_crop_1.jpg',
#  'prescription_Gyne_322_crop_6.jpg',
#  'Neurology_prescription_60_crop_1.jpg',
#  'prescription_Gyne_145_crop_1.jpg',
#  'prescription_Gyne_134_crop_3.jpg',
#  'prescription_Gyne_402_crop_18.jpg',
#  'Dental_prescription_619_crop_10.jpg',
#  'prescription_Gyne_334_crop_7.jpg',
#  'prescription_Gyne_334_crop_15.jpg',
#  'prescription_opth_261_crop_12.jpg',
#  'prescription_Gyne_358_crop_7.jpg',
#  'Neurology_prescription_79_crop_8.jpg',
#  'prescription_Gyne_85_crop_2.jpg',
#  'Neurology_prescription_68_crop_2.jpg',
#  'Neurology_prescription_65_crop_1.jpg',
#  'Dental_prescription_619 (1)_crop_1.jpg',
#  'prescription_Gyne_475_crop_5.jpg',
#  'Dental_prescription_605 (1)_crop_0.jpg',
#  'Neurology_prescription_80_crop_7.jpg',
#  'prescription_Gyne_9_crop_2.jpg',
#  'prescription_Gyne_97_crop_3.jpg',
#  'prescription_Gyne_37_crop_4.jpg',
#  'prescription_Gyne_402_crop_17.jpg',
#  'prescription_Gyne_389_crop_3.jpg',
#  'prescription_Gyne_326_crop_4.jpg',
#  'Dental_prescription_630 (1)_crop_0.jpg',
#  'Dental_prescription_607 (1)_crop_1.jpg',
#  'Dental_prescription_489_crop_3.jpg',
#  'Dental_prescription_488_crop_0.jpg',
#  'prescription_Gyne_117_crop_6.jpg',
#  'Neurology_prescription_57_crop_5.jpg',
#  'prescription_Gyne_444_crop_8.jpg',
#  'prescription_Gyne_62_crop_9.jpg',
#  'prescription_opth_202_crop_5.jpg',
#  'prescription_Gyne_382_crop_6.jpg',
#  'Dental_prescription_620 (1)_crop_2.jpg',
#  'Dental_prescription_489_crop_2.jpg',
#  'prescription_Gyne_389_crop_6.jpg',
#  'Neurology_prescription_57_crop_10.jpg',
#  'prescription_Gyne_322_crop_0.jpg',
#  'prescription_Gyne_404_crop_3.jpg',
#  'Dental_prescription_611 (1)_crop_1.jpg',
#  'prescription_Gyne_382_crop_9.jpg',
#  'prescription_Gyne_149_crop_2.jpg',
#  'Dental_prescription_619_crop_0.jpg',
#  'Dental_prescription_615_crop_10.jpg',
#  'prescription_Gyne_416_crop_6.jpg',
#  'prescription_Gyne_343_crop_4.jpg',
#  'prescription_Gyne_156_crop_6.jpg',
#  'Neurology_prescription_70_crop_5.jpg',
#  'prescription_opth_197_crop_1.jpg',
#  'prescription_Gyne_358_crop_17.jpg',
#  'Neurology_prescription_63_crop_9.jpg',
#  'Dental_prescription_611 (1)_crop_4.jpg',
#  'prescription_opth_261_crop_17.jpg',
#  'Neurology_prescription_79_crop_6.jpg',
#  'prescription_Gyne_337_crop_13.jpg',
#  'prescription_Gyne_59_crop_2.jpg',
#  'prescription_opth_193_crop_13.jpg',
#  'Neurology_prescription_64_crop_0.jpg',
#  'prescription_Gyne_62_crop_2.jpg',
#  'Neurology_prescription_71_crop_6.jpg',
#  'Neurology_prescription_78_crop_4.jpg',
#  'Dental_prescription_611_crop_1.jpg',
#  'prescription_Gyne_393_crop_14.jpg',
#  'prescription_Gyne_447_crop_12.jpg',
#  'Neurology_prescription_69_crop_9.jpg',
#  'Dental_prescription_485_crop_3.jpg',
#  'prescription_opth_193_crop_12.jpg',
#  'Dental_prescription_611_crop_0.jpg',
#  'prescription_Gyne_19_crop_18.jpg',
#  'Neurology_prescription_73_crop_7.jpg',
#  'prescription_Gyne_402_crop_13.jpg',
#  'prescription_Gyne_425_crop_2.jpg',
#  'prescription_Gyne_141_crop_12.jpg',
#  'prescription_opth_198_crop_19.jpg',
#  'Dental_prescription_621_crop_2.jpg',
#  'Neurology_prescription_79_crop_0.jpg',
#  'prescription_opth_230_crop_0.jpg',
#  'prescription_opth_193_crop_10.jpg',
#  'prescription_Gyne_134_crop_10.jpg',
#  'Dental_prescription_482_crop_2.jpg',
#  'prescription_Gyne_475_crop_9.jpg',
#  'prescription_Gyne_326_crop_1.jpg',
#  'prescription_Gyne_335_crop_21.jpg',
#  'Dental_prescription_619 (1)_crop_3.jpg',
#  'prescription_Gyne_358_crop_4.jpg',
#  'prescription_Gyne_141_crop_18.jpg',
#  'Dental_prescription_620 (1)_crop_8.jpg',
#  'prescription_Gyne_38_crop_6.jpg',
#  'prescription_Gyne_326_crop_2.jpg',
#  'Neurology_prescription_67_crop_1.jpg',
#  'Neurology_prescription_57_crop_3.jpg',
#  'Neurology_prescription_77_crop_0.jpg',
#  'Neurology_prescription_76_crop_2.jpg',
#  'prescription_opth_261_crop_11.jpg',
#  'prescription_opth_167_crop_9.jpg',
#  'Dental_prescription_609_crop_11.jpg',
#  'Neurology_prescription_66_crop_0.jpg',
#  'prescription_opth_161_crop_21.jpg',
#  'prescription_Gyne_462_crop_1.jpg',
#  'prescription_Gyne_97_crop_4.jpg',
#  'prescription_Gyne_406_crop_0.jpg',
#  'Neurology_prescription_71_crop_7.jpg',
#  'Neurology_prescription_71_crop_5.jpg',
#  'prescription_opth_230_crop_5.jpg',
#  'prescription_opth_261_crop_13.jpg',
#  'Dental_prescription_488_crop_10.jpg',
#  'Neurology_prescription_73_crop_1.jpg',
#  'prescription_Gyne_18_crop_14.jpg',
#  'prescription_opth_198_crop_26.jpg',
#  'prescription_Gyne_59_crop_16.jpg',
#  'Dental_prescription_542_crop_5.jpg',
#  'prescription_Gyne_322_crop_10.jpg',
#  'prescription_Gyne_334_crop_5.jpg',
#  'prescription_Gyne_462_crop_3.jpg',
#  'prescription_Gyne_444_crop_7.jpg',
#  'prescription_Gyne_38_crop_8.jpg',
#  'Dental_prescription_605 (1)_crop_3.jpg',
#  'Neurology_prescription_63_crop_4.jpg',
#  'prescription_Gyne_444_crop_1.jpg',
#  'Dental_prescription_620 (1)_crop_12.jpg',
#  'prescription_Gyne_470_crop_3.jpg',
#  'Neurology_prescription_62_crop_13.jpg',
#  'Dental_prescription_611 (1)_crop_9.jpg',
#  'prescription_Gyne_447_crop_0.jpg',
#  'prescription_opth_230_crop_6.jpg',
#  'prescription_Gyne_430_crop_3.jpg',
#  'Dental_prescription_625_crop_0.jpg',
#  'prescription_Gyne_430_crop_1.jpg',
#  'Dental_prescription_557_crop_1.jpg',
#  'prescription_Gyne_478_crop_15.jpg',
#  'prescription_Gyne_424_crop_12.jpg',
#  'prescription_Gyne_149_crop_4.jpg',
#  'Dental_prescription_619 (1)_crop_8.jpg',
#  'prescription_Gyne_335_crop_17.jpg',
#  ...}
